# %%
from datetime import datetime
import rasterio , os , glob  #, geojson
from pathlib import PureWindowsPath
from rasterio.plot import show
from rasterio.merge import merge
import rasterio as rio
from pathlib import Path
import shutil
from collections import defaultdict

import rioxarray
from rasterio.mask import mask
import rasterio.plot as rplt
from rasterio.features import rasterize
from rasterio.plot import show
from rasterio.features import shapes
from rasterio import plot
import rasterio as rs
from rasterio import shutil as rio_shutil
from rasterio.vrt import WarpedVRT

from rasterstats import zonal_stats
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.ticker import FuncFormatter
from matplotlib.ticker import ScalarFormatter
from shapely.geometry import LineString, Point
import math

from matplotlib.colors import Normalize
import matplotlib.cm as cm
from matplotlib.lines import Line2D
import matplotlib.pyplot as plt
import matplotlib.text as mtext
from collections import defaultdict
from matplotlib import colormaps

# from h3 import h3
# import h3pandas
import contextily as cx
import matplotlib.colors as colors
import pandas as pd
import numpy as np
import geopandas as gpd
from IPython.display import Image , display
import warnings
warnings.filterwarnings('ignore')
# plt.rcParams['figure.figsize']=9,4
import xarray as xr
from shapely.geometry import mapping, Polygon
import datetime as dt
import matplotlib.dates as mdates
import matplotlib.cm as cm
import matplotlib.patches as mpatches

from dateutil.relativedelta import relativedelta
from rasterio.warp import calculate_default_transform, reproject, Resampling
from geopandas.tools import overlay
from pyproj import CRS
from os.path import exists
import time
from pathlib import Path
# import fiona
from shapely.geometry import Point
from shapely.geometry.polygon import Polygon

import shapefile
from shapely.geometry import shape, Point
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
# Stats heavy-lifting
from libpysal.weights import KNN
from sklearn.preprocessing import robust_scale
from sklearn.cluster import AgglomerativeClustering
import osmnx as ox
from mpl_toolkits.axes_grid1.inset_locator import (inset_axes, TransformedBbox, BboxPatch, BboxConnector)

from collections import defaultdict
from itertools import combinations

import boto3
from shapely.geometry import LineString, MultiPoint
from shapely.ops import split, snap
import datetime

from rasterio import features
from rasterio.plot import show

from utils import set_paths
import yaml

from netCDF4 import Dataset
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap


width=8
height=7

# %%
# socio_econmic=False
cckp=True
socio_econmic=True
cckp=True
WGS84=4326
EPSG_str= 'EPSG:4326'
hexbin_res=8

# %%
# load city inputs files, set paths
with open("configs.yml", 'r') as f:
    configs = yaml.safe_load(f)
print(configs['base_dir'])
base_dir=configs['base_dir']
country=configs['country_name']
city=configs['city_name']

shp=configs['AOI_path']
AOI_path_countries=configs['AOI_path_countries']
vector_file = gpd.read_file(configs['AOI_path']).to_crs(epsg = 4326)
features = vector_file.geometry
aoi_bounds = vector_file.bounds
aoi_file=vector_file
data, shapefiles , maps , rasters , output ,tables = set_paths(base_dir)

all_countries = gpd.read_file((Path(shapefiles)/"WB_countries_Admin0_10m.shp"))
country_shp = all_countries[all_countries.NAME_EN == country]
country_shp.to_file(f"{Path(shapefiles)}/{country}.shp")
country_shp=f"{Path(shapefiles)}/{country}.shp"
# Out:
# D:/Aziz/GFDRR/CRP/FCS/

# %%
# country_shp.explore()

# %%
# # if '__name__' == 'main':
from src import section_1_population ,section_1_1_population,  section_2_gdp, section_2_1_gdp, section_3_urbanland, section_4_heatflux, \
    section_5_urbanheatisland, section_6_cckp, section_7_extremeheat, section_8_infra_demographic_flood_exposure, \
        section_9_demographics, section_10_cyclones, section_11_erosion , section_12_post_processing


country_iso3 = 'BGD'
section= ['demographic']
country_name="Bangladesh"

# section_1_population.create_updated_ssp3_dataset(country_iso3,country_name, city, section, data, tables )
    
# section=["popdynamics"]
# stat=["sum"]
# section_1_population.export_popdynamics(shp, vector_file, stat, section, data ,tables, rasters, country, city)

# section= ['demographic']
# section_2_gdp.create_updated_ssp3_dataset(country_iso3,country_name, city, section, data, tables )
    
# section= ['gdp'] 
# section_2_gdp.export_gdp(shp, vector_file, stat, section, data ,tables, rasters, country, city)
# section= ['urbanland']  
# stat= ['mean']
# section_3_urbanland.export_urbanland(shp, vector_file, stat, section, data ,tables, rasters, country, city)
# section= ['heatflux']
# section_4_heatflux.export_heatflux(shp, vector_file, stat, section, data ,tables, rasters, country, city)

# # Clipping excludes touching all true retctify this
# section= ['urbanheatisland']
# stat= ['mean']
# section_5_urbanheatisland.export_urbanheatisland(shp, vector_file, stat, section, data ,tables, rasters, country, city)

# section= ['Precipitation']
# appended_data= section_6_cckp.export_cckp_data( vector_file, section, data ,tables, country, city)
# export_graph= section_6_cckp.export_cckp_graph(df=appended_data , x_var_name='time', y_var_names='Variable', section=section, maps=maps, country=country, city=city)

# section= ['Temperature']
# appended_data= section_6_cckp.export_cckp_data( vector_file, section, data ,tables, country, city)
# export_graph= section_6_cckp.export_cckp_graph(df=appended_data , x_var_name='time', y_var_names='Variable', section=section, maps=maps, country=country, city=city)

# section= ['Extreme Heat Days']
# df= section_7_extremeheat.export_extreme_heat_cckp_data(vector_file, section, data , rasters, tables, country, city)
# export_graph= section_7_extremeheat.export_extreme_heat_cckp_graph(df=df , x_var_name='time', y_var_names='Variable',maps=maps, section=section,country=country, city=city)   


# flood_bins = [15,30,50,100] 
# revised_bins_list = [15,30,50,100] 
# numberCategories = len(flood_bins)
# rps = configs['flood']['rps']
# flood_threshold = configs['flood']['threshold']
# flood_years = configs['flood']['year']
# flood_ssps = configs['flood']['ssp']

# section_8_infra_demographic_flood_exposure.preprocess_fathom(output, city, aoi_file, country)
# df2=section_8_infra_demographic_flood_exposure.conduct_pop_exposure(output,tables,rasters, vector_file, revised_bins_list , flood_bins, numberCategories, city, country)
# cmap='hsv'
# section_8_infra_demographic_flood_exposure.create_pop_exposure_barchart(df2, revised_bins_list,cmap, maps)

# section_8_infra_demographic_flood_exposure.conduct_infra_exposure_analysis(output, tables ,shapefiles, flood_bins,flood_years, rps ,flood_ssps,  city, country)
# cmap='turbo'
# section_8_infra_demographic_flood_exposure.export_infra_exposure_barcharts(tables, revised_bins_list, cmap, maps,city, country)

# base_path = output
# directories_to_remove = ["Coastal", "Pluvial", "Fluvial"]
# section_8_infra_demographic_flood_exposure.post_process_dir_cleaning(base_path, directories_to_remove)




# country_iso3 = 'BGD'
# section= ['demographic']
# city_pop_ssp2, country_pop_ssp2 = section_9_demographics.demographic_projection(city=city, 
#                                                         country_iso3=country_iso3, 
#                                                         country=country, 
#                                                         ssp_to_use='SSP2', section=section, data=data)

# city_pop_ssp5, country_pop_ssp5 = section_9_demographics.demographic_projection(city=city, 
#                                                         country_iso3=country_iso3, 
#                                                         country=country, 
#                                                         ssp_to_use='SSP5', section=section, data=data)
# city_pop = city_pop_ssp2._append(city_pop_ssp5)
# city_pop = city_pop.loc[city_pop['Year']<=2070]
# city_pop.reset_index(inplace=True, drop=True)

# country_pop = country_pop_ssp2._append(country_pop_ssp5)
# country_pop = country_pop.loc[country_pop['Year']<=2070]
# country_pop.reset_index(inplace=True, drop=True)
# year1_list=[2020, 2050]
# year2_list=[2050, 2070]
# ssp_list=["SSP2", "SSP5"]
# for ssp in ssp_list:
#     section_9_demographics.pop_lineplot(city_pop, ssp, section, maps, city, country)
#     for year1, year2 in zip(year1_list, year2_list):
#         print(year1, year2, ssp)
#         export_pyramid= section_9_demographics.pyramid(city_pop, year1, year2, ssp, section, maps, city, country)


# section= ['tropicalcyclones']
# gdf =vector_file  #gpd.read_file(shp).to_crs(WGS84) #r"inputs/Ukhiya.shp"
# output = section_10_cyclones.get_wind_speed(tables,data, gdf,section, country, city)
# section_10_cyclones.visualize_results(maps,section, output, country, city)

# section= ['globalerosion']
# df=section_11_erosion.process_erosion(tables,data,section, shp, country, city)
# section_11_erosion.map_storms(appended_data=df, shp=shp)
# gdf_shoreline_points=section_11_erosion.create_points(country, shapefiles, df)

# years_multiplier='no_temporal_cumulative'
# transect_gdf, gdf_sorted=section_11_erosion.create_shorelines_transect(country, shapefiles, df, years_multiplier)
# # transect_gdf.explore()
# transect_gdf_attributes=section_11_erosion.trasfer_attributes_to_transects(country, shapefiles, transect_gdf, gdf_sorted,years_multiplier)

# %%
# Example usage
input_directory = rasters  # Update with your input directory
output_directory = f"{output}/shapefiles"  # Update with your output directory
# Ensure the output directory exists
os.makedirs(output_directory, exist_ok=True)
start_keyword = "processed_popdynamics_"  # Replace with your start keyword
end_keyword = ".tif"  # Replace with your end keyword
section_12_post_processing.polygonize_rasters(input_directory, output_directory, start_keyword, end_keyword)

# # Example usage
# input_directory = "path/to/rasters"  # Update with your input directory
# output_directory = "path/to/output"  # Update with your output directory
# start_keyword = "keyword_start"  # Replace with your start keyword
# end_keyword = "keyword_end"  # Replace with your end keyword

# polygonize_rasters(input_directory, output_directory, start_keyword, end_keyword)
# Out:
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP1_2020.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP1_2020.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP1_2025.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP1_2025.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP1_2030.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP1_2030.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP1_2035.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP1_2035.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP1_2040.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP1_2040.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP1_2045.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP1_2045.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP1_2050.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP1_2050.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP1_2055.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP1_2055.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP1_2060.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP1_2060.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP1_2065.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP1_2065.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP1_2070.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP1_2070.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP1_2075.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP1_2075.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP1_2080.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP1_2080.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP1_2085.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP1_2085.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP1_2090.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP1_2090.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP1_2095.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP1_2095.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP1_2100.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP1_2100.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP2_2020.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP2_2020.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP2_2025.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP2_2025.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP2_2030.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP2_2030.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP2_2035.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP2_2035.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP2_2040.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP2_2040.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP2_2045.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP2_2045.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP2_2050.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP2_2050.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP2_2055.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP2_2055.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP2_2060.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP2_2060.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP2_2065.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP2_2065.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP2_2070.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP2_2070.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP2_2075.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP2_2075.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP2_2080.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP2_2080.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP2_2085.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP2_2085.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP2_2090.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP2_2090.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP2_2095.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP2_2095.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP2_2100.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP2_2100.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP3_2020.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP3_2020.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP3_2025.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP3_2025.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP3_2030.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP3_2030.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP3_2035.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP3_2035.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP3_2040.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP3_2040.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP3_2045.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP3_2045.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP3_2050.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP3_2050.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP3_2055.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP3_2055.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP3_2060.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP3_2060.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP3_2065.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP3_2065.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP3_2070.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP3_2070.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP3_2075.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP3_2075.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP3_2080.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP3_2080.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP3_2085.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP3_2085.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP3_2090.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP3_2090.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP3_2095.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP3_2095.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP3_2100.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP3_2100.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP4_2020.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP4_2020.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP4_2025.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP4_2025.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP4_2030.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP4_2030.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP4_2035.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP4_2035.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP4_2040.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP4_2040.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP4_2045.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP4_2045.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP4_2050.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP4_2050.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP4_2055.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP4_2055.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP4_2060.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP4_2060.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP4_2065.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP4_2065.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP4_2070.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP4_2070.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP4_2075.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP4_2075.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP4_2080.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP4_2080.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP4_2085.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP4_2085.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP4_2090.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP4_2090.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP4_2095.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP4_2095.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP4_2100.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP4_2100.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP5_2020.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP5_2020.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP5_2025.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP5_2025.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP5_2030.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP5_2030.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP5_2035.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP5_2035.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP5_2040.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP5_2040.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP5_2045.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP5_2045.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP5_2050.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP5_2050.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP5_2055.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP5_2055.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP5_2060.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP5_2060.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP5_2065.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP5_2065.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP5_2070.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP5_2070.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP5_2075.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP5_2075.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP5_2080.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP5_2080.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP5_2085.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP5_2085.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP5_2090.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP5_2090.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP5_2095.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP5_2095.geojson
# Polygonized D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\processed_popdynamics_SSP5_2100.tif to D:\Aziz\GFDRR\CRP\FCS\02-process-output/shapefiles\processed_popdynamics_SSP5_2100.geojson

# %%
Sdewasd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 Sdewasd
#
# NameError: name 'Sdewasd' is not defined

# %%
  
section=["popdynamics"]
stat=["sum"]

section_1_1_population.export_popdynamics(shp=country_shp, vector_file=vector_file, stat=stat, section=section, data=data ,tables=tables, rasters=rasters, country=country, city=city)
# Example usage
folder_path = rasters
cleaned_section = "".join(map(str, section))
output_csv_path = f"{tables}/{cleaned_section}_city_to_country_ratios.csv"
section_1_1_population.process_rasters_by_prefix_suffix(folder_path, output_csv_path)
# Out:
# SSP1_2020 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP1\SSP1_2020.tif popdynamics
# clip_and_export_rescale_raster done 2
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP1_2020.tif
# Sum: 164601936.0, Mean: 944.9291381835938
# row_df:   Scenario  Year        sum
# 0     SSP1  2020  164601936
# SSP1_2025 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP1\SSP1_2025.tif popdynamics
# year--> 2025  ....ssp_value-->> SSP1...rescaling_factor--->> 1.031974297504538
# rescaling_factor 1.031974297504538
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP1_2025.tif
# Sum: 176025424.0, Mean: 1010.5078735351562
# row_df:   Scenario  Year        sum
# 0     SSP1  2025  176025424
# SSP1_2030 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP1\SSP1_2030.tif popdynamics
# year--> 2030  ....ssp_value-->> SSP1...rescaling_factor--->> 1.0448137579380836
# rescaling_factor 1.0448137579380836
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP1_2030.tif
# Sum: 182776320.0, Mean: 1049.2626953125
# row_df:   Scenario  Year        sum
# 0     SSP1  2030  182776320
# SSP1_2035 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP1\SSP1_2035.tif popdynamics
# year--> 2035  ....ssp_value-->> SSP1...rescaling_factor--->> 1.0533798773240153
# rescaling_factor 1.0533798773240153
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP1_2035.tif
# Sum: 187497552.0, Mean: 1076.3658447265625
# row_df:   Scenario  Year        sum
# 0     SSP1  2035  187497552
# SSP1_2040 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP1\SSP1_2040.tif popdynamics
# year--> 2040  ....ssp_value-->> SSP1...rescaling_factor--->> 1.0594745744392768
# rescaling_factor 1.0594745744392768
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP1_2040.tif
# Sum: 190361424.0, Mean: 1092.8065185546875
# row_df:   Scenario  Year        sum
# 0     SSP1  2040  190361424
# SSP1_2045 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP1\SSP1_2045.tif popdynamics
# year--> 2045  ....ssp_value-->> SSP1...rescaling_factor--->> 1.0662860016296218
# rescaling_factor 1.0662860016296218
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP1_2045.tif
# Sum: 191887760.0, Mean: 1101.5687255859375
# row_df:   Scenario  Year        sum
# 0     SSP1  2045  191887760
# SSP1_2050 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP1\SSP1_2050.tif popdynamics
# year--> 2050  ....ssp_value-->> SSP1...rescaling_factor--->> 1.0742873551064882
# rescaling_factor 1.0742873551064882
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP1_2050.tif
# Sum: 192121248.0, Mean: 1102.9090576171875
# row_df:   Scenario  Year        sum
# 0     SSP1  2050  192121248
# SSP1_2055 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP1\SSP1_2055.tif popdynamics
# year--> 2055  ....ssp_value-->> SSP1...rescaling_factor--->> 1.082834436484815
# rescaling_factor 1.082834436484815
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP1_2055.tif
# Sum: 191144768.0, Mean: 1097.303466796875
# row_df:   Scenario  Year        sum
# 0     SSP1  2055  191144768
# SSP1_2060 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP1\SSP1_2060.tif popdynamics
# year--> 2060  ....ssp_value-->> SSP1...rescaling_factor--->> 1.0912552232826358
# rescaling_factor 1.0912552232826358
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP1_2060.tif
# Sum: 188943824.0, Mean: 1084.66845703125
# row_df:   Scenario  Year        sum
# 0     SSP1  2060  188943824
# SSP1_2065 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP1\SSP1_2065.tif popdynamics
# year--> 2065  ....ssp_value-->> SSP1...rescaling_factor--->> 1.0994234349079697
# rescaling_factor 1.0994234349079697
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP1_2065.tif
# Sum: 185786512.0, Mean: 1066.5433349609375
# row_df:   Scenario  Year        sum
# 0     SSP1  2065  185786512
# SSP1_2070 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP1\SSP1_2070.tif popdynamics
# year--> 2070  ....ssp_value-->> SSP1...rescaling_factor--->> 1.1074238541402817
# rescaling_factor 1.1074238541402817
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP1_2070.tif
# Sum: 181762288.0, Mean: 1043.4415283203125
# row_df:   Scenario  Year        sum
# 0     SSP1  2070  181762288
# SSP1_2075 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP1\SSP1_2075.tif popdynamics
# year--> 2075  ....ssp_value-->> SSP1...rescaling_factor--->> 1.1152093957139133
# rescaling_factor 1.1152093957139133
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP1_2075.tif
# Sum: 176936784.0, Mean: 1015.73974609375
# row_df:   Scenario  Year        sum
# 0     SSP1  2075  176936784
# SSP1_2080 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP1\SSP1_2080.tif popdynamics
# year--> 2080  ....ssp_value-->> SSP1...rescaling_factor--->> 1.123034866119299
# rescaling_factor 1.123034866119299
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP1_2080.tif
# Sum: 171430816.0, Mean: 984.1316528320312
# row_df:   Scenario  Year        sum
# 0     SSP1  2080  171430816
# SSP1_2085 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP1\SSP1_2085.tif popdynamics
# year--> 2085  ....ssp_value-->> SSP1...rescaling_factor--->> 1.1309663124288496
# rescaling_factor 1.1309663124288496
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP1_2085.tif
# Sum: 165369440.0, Mean: 949.3351440429688
# row_df:   Scenario  Year        sum
# 0     SSP1  2085  165369440
# SSP1_2090 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP1\SSP1_2090.tif popdynamics
# year--> 2090  ....ssp_value-->> SSP1...rescaling_factor--->> 1.139022150376098
# rescaling_factor 1.139022150376098
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP1_2090.tif
# Sum: 158853376.0, Mean: 911.928466796875
# row_df:   Scenario  Year        sum
# 0     SSP1  2090  158853376
# SSP1_2095 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP1\SSP1_2095.tif popdynamics
# year--> 2095  ....ssp_value-->> SSP1...rescaling_factor--->> 1.1467600804773992
# rescaling_factor 1.1467600804773992
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP1_2095.tif
# Sum: 151964224.0, Mean: 872.3799438476562
# row_df:   Scenario  Year        sum
# 0     SSP1  2095  151964224
# SSP1_2100 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP1\SSP1_2100.tif popdynamics
# year--> 2100  ....ssp_value-->> SSP1...rescaling_factor--->> 1.1539957711118585
# rescaling_factor 1.1539957711118585
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP1_2100.tif
# Sum: 144828064.0, Mean: 831.4134521484375
# row_df:   Scenario  Year        sum
# 0     SSP1  2100  144828064
# SSP2_2020 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP2\SSP2_2020.tif popdynamics
# clip_and_export_rescale_raster done 2
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP2_2020.tif
# Sum: 167305296.0, Mean: 960.4483032226562
# row_df:   Scenario  Year        sum
# 0     SSP2  2020  167305296
# SSP2_2025 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP2\SSP2_2025.tif popdynamics
# year--> 2025  ....ssp_value-->> SSP2...rescaling_factor--->> 1.007111499658312
# rescaling_factor 1.007111499658312
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP2_2025.tif
# Sum: 176667552.0, Mean: 1014.1941528320312
# row_df:   Scenario  Year        sum
# 0     SSP2  2025  176667552
# SSP2_2030 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP2\SSP2_2030.tif popdynamics
# year--> 2030  ....ssp_value-->> SSP2...rescaling_factor--->> 1.0122973739331291
# rescaling_factor 1.0122973739331291
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP2_2030.tif
# Sum: 184561248.0, Mean: 1059.5093994140625
# row_df:   Scenario  Year        sum
# 0     SSP2  2030  184561248
# SSP2_2035 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP2\SSP2_2035.tif popdynamics
# year--> 2035  ....ssp_value-->> SSP2...rescaling_factor--->> 1.015057055052057
# rescaling_factor 1.015057055052057
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP2_2035.tif
# Sum: 190777712.0, Mean: 1095.1962890625
# row_df:   Scenario  Year        sum
# 0     SSP2  2035  190777712
# SSP2_2040 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP2\SSP2_2040.tif popdynamics
# year--> 2040  ....ssp_value-->> SSP2...rescaling_factor--->> 1.0160613130629166
# rescaling_factor 1.0160613130629166
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP2_2040.tif
# Sum: 195425168.0, Mean: 1121.8758544921875
# row_df:   Scenario  Year        sum
# 0     SSP2  2040  195425168
# SSP2_2045 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP2\SSP2_2045.tif popdynamics
# year--> 2045  ....ssp_value-->> SSP2...rescaling_factor--->> 1.0167092564562308
# rescaling_factor 1.0167092564562308
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP2_2045.tif
# Sum: 198639504.0, Mean: 1140.328369140625
# row_df:   Scenario  Year        sum
# 0     SSP2  2045  198639504
# SSP2_2050 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP2\SSP2_2050.tif popdynamics
# year--> 2050  ....ssp_value-->> SSP2...rescaling_factor--->> 1.0179123239621777
# rescaling_factor 1.0179123239621777
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP2_2050.tif
# Sum: 200594080.0, Mean: 1151.5489501953125
# row_df:   Scenario  Year        sum
# 0     SSP2  2050  200594080
# SSP2_2055 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP2\SSP2_2055.tif popdynamics
# year--> 2055  ....ssp_value-->> SSP2...rescaling_factor--->> 1.020416367385396
# rescaling_factor 1.020416367385396
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP2_2055.tif
# Sum: 201435328.0, Mean: 1156.37841796875
# row_df:   Scenario  Year        sum
# 0     SSP2  2055  201435328
# SSP2_2060 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP2\SSP2_2060.tif popdynamics
# year--> 2060  ....ssp_value-->> SSP2...rescaling_factor--->> 1.0236859767693332
# rescaling_factor 1.0236859767693332
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP2_2060.tif
# Sum: 201104688.0, Mean: 1154.480224609375
# row_df:   Scenario  Year        sum
# 0     SSP2  2060  201104688
# SSP2_2065 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP2\SSP2_2065.tif popdynamics
# year--> 2065  ....ssp_value-->> SSP2...rescaling_factor--->> 1.0266879897959125
# rescaling_factor 1.0266879897959125
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP2_2065.tif
# Sum: 199731568.0, Mean: 1146.5975341796875
# row_df:   Scenario  Year        sum
# 0     SSP2  2065  199731568
# SSP2_2070 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP2\SSP2_2070.tif popdynamics
# year--> 2070  ....ssp_value-->> SSP2...rescaling_factor--->> 1.0285500665630092
# rescaling_factor 1.0285500665630092
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP2_2070.tif
# Sum: 197422224.0, Mean: 1133.34033203125
# row_df:   Scenario  Year        sum
# 0     SSP2  2070  197422224
# SSP2_2075 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP2\SSP2_2075.tif popdynamics
# year--> 2075  ....ssp_value-->> SSP2...rescaling_factor--->> 1.0295927672331775
# rescaling_factor 1.0295927672331775
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP2_2075.tif
# Sum: 194351440.0, Mean: 1115.7119140625
# row_df:   Scenario  Year        sum
# 0     SSP2  2075  194351440
# SSP2_2080 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP2\SSP2_2080.tif popdynamics
# year--> 2080  ....ssp_value-->> SSP2...rescaling_factor--->> 1.030106368831769
# rescaling_factor 1.030106368831769
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP2_2080.tif
# Sum: 190694928.0, Mean: 1094.7210693359375
# row_df:   Scenario  Year        sum
# 0     SSP2  2080  190694928
# SSP2_2085 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP2\SSP2_2085.tif popdynamics
# year--> 2085  ....ssp_value-->> SSP2...rescaling_factor--->> 1.029831307529689
# rescaling_factor 1.029831307529689
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP2_2085.tif
# Sum: 186539152.0, Mean: 1070.864013671875
# row_df:   Scenario  Year        sum
# 0     SSP2  2085  186539152
# SSP2_2090 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP2\SSP2_2090.tif popdynamics
# year--> 2090  ....ssp_value-->> SSP2...rescaling_factor--->> 1.028447673257504
# rescaling_factor 1.028447673257504
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP2_2090.tif
# Sum: 181998272.0, Mean: 1044.796142578125
# row_df:   Scenario  Year        sum
# 0     SSP2  2090  181998272
# SSP2_2095 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP2\SSP2_2095.tif popdynamics
# year--> 2095  ....ssp_value-->> SSP2...rescaling_factor--->> 1.025738081486092
# rescaling_factor 1.025738081486092
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP2_2095.tif
# Sum: 177212112.0, Mean: 1017.3203125
# row_df:   Scenario  Year        sum
# 0     SSP2  2095  177212112
# SSP2_2100 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP2\SSP2_2100.tif popdynamics
# year--> 2100  ....ssp_value-->> SSP2...rescaling_factor--->> 1.0227336980334456
# rescaling_factor 1.0227336980334456
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP2_2100.tif
# Sum: 172467168.0, Mean: 990.0810546875
# row_df:   Scenario  Year        sum
# 0     SSP2  2100  172467168
# SSP3_2020 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP3\SSP3_2020.tif popdynamics
# clip_and_export_rescale_raster done 2
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP3_2020.tif
# Sum: 170087168.0, Mean: 976.418212890625
# row_df:   Scenario  Year        sum
# 0     SSP3  2020  170087168
# SSP3_2025 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP3\SSP3_2025.tif popdynamics
# year--> 2025  ....ssp_value-->> SSP3...rescaling_factor--->> 0.9814203547433872
# rescaling_factor 0.9814203547433872
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP3_2025.tif
# Sum: 177720736.0, Mean: 1020.2401733398438
# row_df:   Scenario  Year        sum
# 0     SSP3  2025  177720736
# SSP3_2030 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP3\SSP3_2030.tif popdynamics
# year--> 2030  ....ssp_value-->> SSP3...rescaling_factor--->> 0.978162118617155
# rescaling_factor 0.978162118617155
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP3_2030.tif
# Sum: 187298384.0, Mean: 1075.2225341796875
# row_df:   Scenario  Year        sum
# 0     SSP3  2030  187298384
# SSP3_2035 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP3\SSP3_2035.tif popdynamics
# year--> 2035  ....ssp_value-->> SSP3...rescaling_factor--->> 0.9745248981627724
# rescaling_factor 0.9745248981627724
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP3_2035.tif
# Sum: 195592096.0, Mean: 1122.8341064453125
# row_df:   Scenario  Year        sum
# 0     SSP3  2035  195592096
# SSP3_2040 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP3\SSP3_2040.tif popdynamics
# year--> 2040  ....ssp_value-->> SSP3...rescaling_factor--->> 0.970027046508072
# rescaling_factor 0.970027046508072
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP3_2040.tif
# Sum: 202681584.0, Mean: 1163.53271484375
# row_df:   Scenario  Year        sum
# 0     SSP3  2040  202681584
# SSP3_2045 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP3\SSP3_2045.tif popdynamics
# year--> 2045  ....ssp_value-->> SSP3...rescaling_factor--->> 0.962780152044842
# rescaling_factor 0.962780152044842
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP3_2045.tif
# Sum: 208378384.0, Mean: 1196.236328125
# row_df:   Scenario  Year        sum
# 0     SSP3  2045  208378384
# SSP3_2050 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP3\SSP3_2050.tif popdynamics
# year--> 2050  ....ssp_value-->> SSP3...rescaling_factor--->> 0.9549130938613396
# rescaling_factor 0.9549130938613396
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP3_2050.tif
# Sum: 213004608.0, Mean: 1222.7940673828125
# row_df:   Scenario  Year        sum
# 0     SSP3  2050  213004608
# SSP3_2055 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP3\SSP3_2055.tif popdynamics
# year--> 2055  ....ssp_value-->> SSP3...rescaling_factor--->> 0.9480071245606484
# rescaling_factor 0.9480071245606484
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP3_2055.tif
# Sum: 216770368.0, Mean: 1244.412109375
# row_df:   Scenario  Year        sum
# 0     SSP3  2055  216770368
# SSP3_2060 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP3\SSP3_2060.tif popdynamics
# year--> 2060  ....ssp_value-->> SSP3...rescaling_factor--->> 0.9418954713423248
# rescaling_factor 0.9418954713423248
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP3_2060.tif
# Sum: 219579632.0, Mean: 1260.5391845703125
# row_df:   Scenario  Year        sum
# 0     SSP3  2060  219579632
# SSP3_2065 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP3\SSP3_2065.tif popdynamics
# year--> 2065  ....ssp_value-->> SSP3...rescaling_factor--->> 0.9345658452943852
# rescaling_factor 0.9345658452943852
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP3_2065.tif
# Sum: 221327168.0, Mean: 1270.5712890625
# row_df:   Scenario  Year        sum
# 0     SSP3  2065  221327168
# SSP3_2070 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP3\SSP3_2070.tif popdynamics
# year--> 2070  ....ssp_value-->> SSP3...rescaling_factor--->> 0.9246440488394329
# rescaling_factor 0.9246440488394329
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP3_2070.tif
# Sum: 222117872.0, Mean: 1275.1104736328125
# row_df:   Scenario  Year        sum
# 0     SSP3  2070  222117872
# SSP3_2075 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP3\SSP3_2075.tif popdynamics
# year--> 2075  ....ssp_value-->> SSP3...rescaling_factor--->> 0.9127776473517102
# rescaling_factor 0.9127776473517102
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP3_2075.tif
# Sum: 222219680.0, Mean: 1275.6949462890625
# row_df:   Scenario  Year        sum
# 0     SSP3  2075  222219680
# SSP3_2080 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP3\SSP3_2080.tif popdynamics
# year--> 2080  ....ssp_value-->> SSP3...rescaling_factor--->> 0.8992570555992513
# rescaling_factor 0.8992570555992513
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP3_2080.tif
# Sum: 221908320.0, Mean: 1273.907470703125
# row_df:   Scenario  Year        sum
# 0     SSP3  2080  221908320
# SSP3_2085 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP3\SSP3_2085.tif popdynamics
# year--> 2085  ....ssp_value-->> SSP3...rescaling_factor--->> 0.8841437577411047
# rescaling_factor 0.8841437577411047
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP3_2085.tif
# Sum: 221304112.0, Mean: 1270.43896484375
# row_df:   Scenario  Year        sum
# 0     SSP3  2085  221304112
# SSP3_2090 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP3\SSP3_2090.tif popdynamics
# year--> 2090  ....ssp_value-->> SSP3...rescaling_factor--->> 0.8675192711698885
# rescaling_factor 0.8675192711698885
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP3_2090.tif
# Sum: 220508848.0, Mean: 1265.87353515625
# row_df:   Scenario  Year        sum
# 0     SSP3  2090  220508848
# SSP3_2095 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP3\SSP3_2095.tif popdynamics
# year--> 2095  ....ssp_value-->> SSP3...rescaling_factor--->> 0.8499252934638372
# rescaling_factor 0.8499252934638372
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP3_2095.tif
# Sum: 219708960.0, Mean: 1261.2816162109375
# row_df:   Scenario  Year        sum
# 0     SSP3  2095  219708960
# SSP3_2100 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP3\SSP3_2100.tif popdynamics
# year--> 2100  ....ssp_value-->> SSP3...rescaling_factor--->> 0.832908256714207
# rescaling_factor 0.832908256714207
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP3_2100.tif
# Sum: 219297088.0, Mean: 1258.917236328125
# row_df:   Scenario  Year        sum
# 0     SSP3  2100  219297088
# SSP4_2020 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP4\SSP4_2020.tif popdynamics
# clip_and_export_rescale_raster done 2
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP4_2020.tif
# Sum: 164955792.0, Mean: 946.9605712890625
# row_df:   Scenario  Year        sum
# 0     SSP4  2020  164955792
# SSP4_2025 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP4\SSP4_2025.tif popdynamics
# year--> 2025  ....ssp_value-->> SSP4...rescaling_factor--->> 1.035952720913878
# rescaling_factor 1.035952720913878
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP4_2025.tif
# Sum: 177250064.0, Mean: 1017.5382080078125
# row_df:   Scenario  Year        sum
# 0     SSP4  2025  177250064
# SSP4_2030 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP4\SSP4_2030.tif popdynamics
# year--> 2030  ....ssp_value-->> SSP4...rescaling_factor--->> 1.0614529337069984
# rescaling_factor 1.0614529337069984
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP4_2030.tif
# Sum: 186286768.0, Mean: 1069.4151611328125
# row_df:   Scenario  Year        sum
# 0     SSP4  2030  186286768
# SSP4_2035 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP4\SSP4_2035.tif popdynamics
# year--> 2035  ....ssp_value-->> SSP4...rescaling_factor--->> 1.0867453159056732
# rescaling_factor 1.0867453159056732
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP4_2035.tif
# Sum: 193976816.0, Mean: 1113.561279296875
# row_df:   Scenario  Year        sum
# 0     SSP4  2035  193976816
# SSP4_2040 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP4\SSP4_2040.tif popdynamics
# year--> 2040  ....ssp_value-->> SSP4...rescaling_factor--->> 1.1135715570418805
# rescaling_factor 1.1135715570418805
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP4_2040.tif
# Sum: 200420512.0, Mean: 1150.5526123046875
# row_df:   Scenario  Year        sum
# 0     SSP4  2040  200420512
# SSP4_2045 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP4\SSP4_2045.tif popdynamics
# year--> 2045  ....ssp_value-->> SSP4...rescaling_factor--->> 1.1420663156663675
# rescaling_factor 1.1420663156663675
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP4_2045.tif
# Sum: 205437360.0, Mean: 1179.352783203125
# row_df:   Scenario  Year        sum
# 0     SSP4  2045  205437360
# SSP4_2050 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP4\SSP4_2050.tif popdynamics
# year--> 2050  ....ssp_value-->> SSP4...rescaling_factor--->> 1.17448620851711
# rescaling_factor 1.17448620851711
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP4_2050.tif
# Sum: 209348752.0, Mean: 1201.806884765625
# row_df:   Scenario  Year        sum
# 0     SSP4  2050  209348752
# SSP4_2055 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP4\SSP4_2055.tif popdynamics
# year--> 2055  ....ssp_value-->> SSP4...rescaling_factor--->> 1.2119851803328945
# rescaling_factor 1.2119851803328945
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP4_2055.tif
# Sum: 212378368.0, Mean: 1219.198974609375
# row_df:   Scenario  Year        sum
# 0     SSP4  2055  212378368
# SSP4_2060 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP4\SSP4_2060.tif popdynamics
# year--> 2060  ....ssp_value-->> SSP4...rescaling_factor--->> 1.254164259786055
# rescaling_factor 1.254164259786055
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP4_2060.tif
# Sum: 214441152.0, Mean: 1231.040771484375
# row_df:   Scenario  Year        sum
# 0     SSP4  2060  214441152
# SSP4_2065 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP4\SSP4_2065.tif popdynamics
# year--> 2065  ....ssp_value-->> SSP4...rescaling_factor--->> 1.299797084111853
# rescaling_factor 1.299797084111853
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP4_2065.tif
# Sum: 215504240.0, Mean: 1237.1436767578125
# row_df:   Scenario  Year        sum
# 0     SSP4  2065  215504240
# SSP4_2070 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP4\SSP4_2070.tif popdynamics
# year--> 2070  ....ssp_value-->> SSP4...rescaling_factor--->> 1.3498949022037892
# rescaling_factor 1.3498949022037892
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP4_2070.tif
# Sum: 215686880.0, Mean: 1238.192138671875
# row_df:   Scenario  Year        sum
# 0     SSP4  2070  215686880
# SSP4_2075 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP4\SSP4_2075.tif popdynamics
# year--> 2075  ....ssp_value-->> SSP4...rescaling_factor--->> 1.4057941048190767
# rescaling_factor 1.4057941048190767
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP4_2075.tif
# Sum: 215241824.0, Mean: 1235.63720703125
# row_df:   Scenario  Year        sum
# 0     SSP4  2075  215241824
# SSP4_2080 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP4\SSP4_2080.tif popdynamics
# year--> 2080  ....ssp_value-->> SSP4...rescaling_factor--->> 1.468947561458092
# rescaling_factor 1.468947561458092
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP4_2080.tif
# Sum: 214448384.0, Mean: 1231.082275390625
# row_df:   Scenario  Year        sum
# 0     SSP4  2080  214448384
# SSP4_2085 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP4\SSP4_2085.tif popdynamics
# year--> 2085  ....ssp_value-->> SSP4...rescaling_factor--->> 1.5399180288361909
# rescaling_factor 1.5399180288361909
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP4_2085.tif
# Sum: 213444064.0, Mean: 1225.3167724609375
# row_df:   Scenario  Year        sum
# 0     SSP4  2085  213444064
# SSP4_2090 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP4\SSP4_2090.tif popdynamics
# year--> 2090  ....ssp_value-->> SSP4...rescaling_factor--->> 1.6190230164030008
# rescaling_factor 1.6190230164030008
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP4_2090.tif
# Sum: 212351136.0, Mean: 1219.0426025390625
# row_df:   Scenario  Year        sum
# 0     SSP4  2090  212351136
# SSP4_2095 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP4\SSP4_2095.tif popdynamics
# year--> 2095  ....ssp_value-->> SSP4...rescaling_factor--->> 1.7070994749896762
# rescaling_factor 1.7070994749896762
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP4_2095.tif
# Sum: 211356832.0, Mean: 1213.334716796875
# row_df:   Scenario  Year        sum
# 0     SSP4  2095  211356832
# SSP4_2100 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP4\SSP4_2100.tif popdynamics
# year--> 2100  ....ssp_value-->> SSP4...rescaling_factor--->> 1.806880599476445
# rescaling_factor 1.806880599476445
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP4_2100.tif
# Sum: 210835808.0, Mean: 1210.3436279296875
# row_df:   Scenario  Year        sum
# 0     SSP4  2100  210835808
# SSP5_2020 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP5\SSP5_2020.tif popdynamics
# clip_and_export_rescale_raster done 2
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP5_2020.tif
# Sum: 163633504.0, Mean: 939.3696899414062
# row_df:   Scenario  Year        sum
# 0     SSP5  2020  163633504
# SSP5_2025 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP5\SSP5_2025.tif popdynamics
# year--> 2025  ....ssp_value-->> SSP5...rescaling_factor--->> 1.0378742809642365
# rescaling_factor 1.0378742809642365
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP5_2025.tif
# Sum: 175065968.0, Mean: 1004.9999389648438
# row_df:   Scenario  Year        sum
# 0     SSP5  2025  175065968
# SSP5_2030 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP5\SSP5_2030.tif popdynamics
# year--> 2030  ....ssp_value-->> SSP5...rescaling_factor--->> 1.050433255166731
# rescaling_factor 1.050433255166731
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP5_2030.tif
# Sum: 180754016.0, Mean: 1037.6533203125
# row_df:   Scenario  Year        sum
# 0     SSP5  2030  180754016
# SSP5_2035 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP5\SSP5_2035.tif popdynamics
# year--> 2035  ....ssp_value-->> SSP5...rescaling_factor--->> 1.058546724560604
# rescaling_factor 1.058546724560604
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP5_2035.tif
# Sum: 184364320.0, Mean: 1058.37890625
# row_df:   Scenario  Year        sum
# 0     SSP5  2035  184364320
# SSP5_2040 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP5\SSP5_2040.tif popdynamics
# year--> 2040  ....ssp_value-->> SSP5...rescaling_factor--->> 1.0641399868049188
# rescaling_factor 1.0641399868049188
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP5_2040.tif
# Sum: 186112928.0, Mean: 1068.4171142578125
# row_df:   Scenario  Year        sum
# 0     SSP5  2040  186112928
# SSP5_2045 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP5\SSP5_2045.tif popdynamics
# year--> 2045  ....ssp_value-->> SSP5...rescaling_factor--->> 1.0704668092652374
# rescaling_factor 1.0704668092652374
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP5_2045.tif
# Sum: 186532368.0, Mean: 1070.8250732421875
# row_df:   Scenario  Year        sum
# 0     SSP5  2045  186532368
# SSP5_2050 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP5\SSP5_2050.tif popdynamics
# year--> 2050  ....ssp_value-->> SSP5...rescaling_factor--->> 1.0779621055898216
# rescaling_factor 1.0779621055898216
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP5_2050.tif
# Sum: 185682944.0, Mean: 1065.94873046875
# row_df:   Scenario  Year        sum
# 0     SSP5  2050  185682944
# SSP5_2055 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP5\SSP5_2055.tif popdynamics
# year--> 2055  ....ssp_value-->> SSP5...rescaling_factor--->> 1.0859235812686758
# rescaling_factor 1.0859235812686758
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP5_2055.tif
# Sum: 183661488.0, Mean: 1054.34423828125
# row_df:   Scenario  Year        sum
# 0     SSP5  2055  183661488
# SSP5_2060 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP5\SSP5_2060.tif popdynamics
# year--> 2060  ....ssp_value-->> SSP5...rescaling_factor--->> 1.0936697877053692
# rescaling_factor 1.0936697877053692
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP5_2060.tif
# Sum: 180473312.0, Mean: 1036.0418701171875
# row_df:   Scenario  Year        sum
# 0     SSP5  2060  180473312
# SSP5_2065 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP5\SSP5_2065.tif popdynamics
# year--> 2065  ....ssp_value-->> SSP5...rescaling_factor--->> 1.1012002408116393
# rescaling_factor 1.1012002408116393
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP5_2065.tif
# Sum: 176509184.0, Mean: 1013.2850341796875
# row_df:   Scenario  Year        sum
# 0     SSP5  2065  176509184
# SSP5_2070 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP5\SSP5_2070.tif popdynamics
# year--> 2070  ....ssp_value-->> SSP5...rescaling_factor--->> 1.1086000256949309
# rescaling_factor 1.1086000256949309
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP5_2070.tif
# Sum: 171860640.0, Mean: 986.5991821289062
# row_df:   Scenario  Year        sum
# 0     SSP5  2070  171860640
# SSP5_2075 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP5\SSP5_2075.tif popdynamics
# year--> 2075  ....ssp_value-->> SSP5...rescaling_factor--->> 1.1158028354007827
# rescaling_factor 1.1158028354007827
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP5_2075.tif
# Sum: 166599024.0, Mean: 956.3938598632812
# row_df:   Scenario  Year        sum
# 0     SSP5  2075  166599024
# SSP5_2080 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP5\SSP5_2080.tif popdynamics
# year--> 2080  ....ssp_value-->> SSP5...rescaling_factor--->> 1.123093338205728
# rescaling_factor 1.123093338205728
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP5_2080.tif
# Sum: 160842880.0, Mean: 923.349609375
# row_df:   Scenario  Year        sum
# 0     SSP5  2080  160842880
# SSP5_2085 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP5\SSP5_2085.tif popdynamics
# year--> 2085  ....ssp_value-->> SSP5...rescaling_factor--->> 1.1306288164964144
# rescaling_factor 1.1306288164964144
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP5_2085.tif
# Sum: 154715296.0, Mean: 888.1729736328125
# row_df:   Scenario  Year        sum
# 0     SSP5  2085  154715296
# SSP5_2090 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP5\SSP5_2090.tif popdynamics
# year--> 2090  ....ssp_value-->> SSP5...rescaling_factor--->> 1.138563609742507
# rescaling_factor 1.138563609742507
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP5_2090.tif
# Sum: 148320976.0, Mean: 851.4651489257812
# row_df:   Scenario  Year        sum
# 0     SSP5  2090  148320976
# SSP5_2095 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP5\SSP5_2095.tif popdynamics
# year--> 2095  ....ssp_value-->> SSP5...rescaling_factor--->> 1.1465830333997342
# rescaling_factor 1.1465830333997342
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP5_2095.tif
# Sum: 141734512.0, Mean: 813.654296875
# row_df:   Scenario  Year        sum
# 0     SSP5  2095  141734512
# SSP5_2100 D:/Aziz/GFDRR/CRP/FCS/data\popdynamics\wang\SPP5\SSP5_2100.tif popdynamics
# year--> 2100  ....ssp_value-->> SSP5...rescaling_factor--->> 1.1545688934833882
# rescaling_factor 1.1545688934833882
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_popdynamics_SSP5_2100.tif
# Sum: 135071456.0, Mean: 775.4037475585938
# row_df:   Scenario  Year        sum
# 0     SSP5  2100  135071456
# No matching raster found for suffix 'heatflux_AHE_2050_01_average.tif' in Bangladesh files.
# No matching raster found for suffix 'heatflux_AHE_2050_02_average.tif' in Bangladesh files.
# No matching raster found for suffix 'heatflux_AHE_2050_03_average.tif' in Bangladesh files.
# No matching raster found for suffix 'heatflux_AHE_2050_04_average.tif' in Bangladesh files.
# No matching raster found for suffix 'heatflux_AHE_2050_05_average.tif' in Bangladesh files.
# No matching raster found for suffix 'heatflux_AHE_2050_06_average.tif' in Bangladesh files.
# No matching raster found for suffix 'heatflux_AHE_2050_07_average.tif' in Bangladesh files.
# No matching raster found for suffix 'heatflux_AHE_2050_08_average.tif' in Bangladesh files.
# No matching raster found for suffix 'heatflux_AHE_2050_09_average.tif' in Bangladesh files.
# No matching raster found for suffix 'heatflux_AHE_2050_10_average.tif' in Bangladesh files.
# No matching raster found for suffix 'heatflux_AHE_2050_11_average.tif' in Bangladesh files.
# No matching raster found for suffix 'heatflux_AHE_2050_12_average.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp1_day_sum.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp1_day_win.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp1_nig_sum.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp1_nig_win.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp2_day_sum.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp2_day_win.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp2_nig_sum.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp2_nig_win.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp3_day_sum.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp3_day_win.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp3_nig_sum.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp3_nig_win.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp4_day_sum.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp4_day_win.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp4_nig_sum.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp4_nig_win.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp5_day_sum.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp5_day_win.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp5_nig_sum.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp5_nig_win.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp1_2010.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp1_2020.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp1_2030.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp1_2040.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp1_2050.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp1_2060.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp1_2070.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp1_2080.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp1_2090.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp1_2100.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp2_2010.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp2_2020.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp2_2030.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp2_2040.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp2_2050.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp2_2060.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp2_2070.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp2_2080.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp2_2090.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp2_2100.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp3_2010.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp3_2020.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp3_2030.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp3_2040.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp3_2050.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp3_2060.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp3_2070.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp3_2080.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp3_2090.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp3_2100.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp4_2010.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp4_2020.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp4_2030.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp4_2040.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp4_2050.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp4_2060.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp4_2070.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp4_2080.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp4_2090.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp4_2100.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp5_2010.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp5_2020.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp5_2030.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp5_2040.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp5_2050.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp5_2060.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp5_2070.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp5_2080.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp5_2090.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp5_2100.tif' in Bangladesh files.

# %%
section= ['gdp'] 
stat=["sum"]
section_2_1_gdp.export_gdp(shp=country_shp, vector_file=vector_file, stat=stat, section=section, data=data ,tables=tables, rasters=rasters, country=country, city=city)
# section_2_gdp.section_(shp=country_shp, vector_file=vector_file, stat=stat, section=section, data=data ,tables=tables, rasters=rasters, country=country, city=city)
# Example usage
folder_path = rasters
cleaned_section = "".join(map(str, section))
# output_csv_path = f"{tables}/{cleaned_section}_city_to_country_ratios.csv"
# section_2_1_gdp.process_rasters_by_prefix_suffix(folder_path, output_csv_path)

output_csv_path = f"{tables}/{cleaned_section}_city_to_country_ratios.csv"
section_2_1_gdp.process_gdp_rasters(folder_path, output_csv_path)
print(f"Results exported to {output_csv_path}")
# Out:
# GDP2025_ssp1 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP1\GDP2025_ssp1.tif gdp
# year--> 2025  ....ssp_value-->> SSP1...rescaling_factor--->> 1.314097729668313
# rescaling_factor 1.314097729668313
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2025_ssp1.tif
# Sum: 1151334744064.0, Mean: 6648197.0
# row_df:   Scenario  Year            sum
# 0     SSP1  2025  1151334744064
# GDP2030_ssp1 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP1\GDP2030_ssp1.tif gdp
# year--> 2030  ....ssp_value-->> SSP1...rescaling_factor--->> 1.131836564530687
# rescaling_factor 1.131836564530687
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2030_ssp1.tif
# Sum: 1322568384512.0, Mean: 7636958.0
# row_df:   Scenario  Year            sum
# 0     SSP1  2030  1322568384512
# GDP2035_ssp1 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP1\GDP2035_ssp1.tif gdp
# year--> 2035  ....ssp_value-->> SSP1...rescaling_factor--->> 1.123393581940518
# rescaling_factor 1.123393581940518
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2035_ssp1.tif
# Sum: 1720756731904.0, Mean: 9936232.0
# row_df:   Scenario  Year            sum
# 0     SSP1  2035  1720756731904
# GDP2040_ssp1 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP1\GDP2040_ssp1.tif gdp
# year--> 2040  ....ssp_value-->> SSP1...rescaling_factor--->> 1.1221613209536403
# rescaling_factor 1.1221613209536403
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2040_ssp1.tif
# Sum: 2213632016384.0, Mean: 12782261.0
# row_df:   Scenario  Year            sum
# 0     SSP1  2040  2213632016384
# GDP2045_ssp1 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP1\GDP2045_ssp1.tif gdp
# year--> 2045  ....ssp_value-->> SSP1...rescaling_factor--->> 1.1465398897120145
# rescaling_factor 1.1465398897120145
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2045_ssp1.tif
# Sum: 2861857243136.0, Mean: 16525333.0
# row_df:   Scenario  Year            sum
# 0     SSP1  2045  2861857243136
# GDP2050_ssp1 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP1\GDP2050_ssp1.tif gdp
# year--> 2050  ....ssp_value-->> SSP1...rescaling_factor--->> 1.1704897590458403
# rescaling_factor 1.1704897590458403
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2050_ssp1.tif
# Sum: 3611483701248.0, Mean: 20853930.0
# row_df:   Scenario  Year            sum
# 0     SSP1  2050  3611483701248
# GDP2055_ssp1 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP1\GDP2055_ssp1.tif gdp
# year--> 2055  ....ssp_value-->> SSP1...rescaling_factor--->> 1.1956224460849978
# rescaling_factor 1.1956224460849978
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2055_ssp1.tif
# Sum: 4467462242304.0, Mean: 25796640.0
# row_df:   Scenario  Year            sum
# 0     SSP1  2055  4467462242304
# GDP2060_ssp1 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP1\GDP2060_ssp1.tif gdp
# year--> 2060  ....ssp_value-->> SSP1...rescaling_factor--->> 1.1921003650497344
# rescaling_factor 1.1921003650497344
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2060_ssp1.tif
# Sum: 5271609933824.0, Mean: 30440062.0
# row_df:   Scenario  Year            sum
# 0     SSP1  2060  5271609933824
# GDP2065_ssp1 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP1\GDP2065_ssp1.tif gdp
# year--> 2065  ....ssp_value-->> SSP1...rescaling_factor--->> 1.1904084262111438
# rescaling_factor 1.1904084262111438
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2065_ssp1.tif
# Sum: 6086250725376.0, Mean: 35144072.0
# row_df:   Scenario  Year            sum
# 0     SSP1  2065  6086250725376
# GDP2070_ssp1 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP1\GDP2070_ssp1.tif gdp
# year--> 2070  ....ssp_value-->> SSP1...rescaling_factor--->> 1.1926259037902402
# rescaling_factor 1.1926259037902402
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2070_ssp1.tif
# Sum: 6908772089856.0, Mean: 39893592.0
# row_df:   Scenario  Year            sum
# 0     SSP1  2070  6908772089856
# GDP2075_ssp1 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP1\GDP2075_ssp1.tif gdp
# year--> 2075  ....ssp_value-->> SSP1...rescaling_factor--->> 1.208681358521339
# rescaling_factor 1.208681358521339
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2075_ssp1.tif
# Sum: 7794302386176.0, Mean: 45006944.0
# row_df:   Scenario  Year            sum
# 0     SSP1  2075  7794302386176
# GDP2080_ssp1 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP1\GDP2080_ssp1.tif gdp
# year--> 2080  ....ssp_value-->> SSP1...rescaling_factor--->> 1.2300711410640657
# rescaling_factor 1.2300711410640657
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2080_ssp1.tif
# Sum: 8709712904192.0, Mean: 50292832.0
# row_df:   Scenario  Year            sum
# 0     SSP1  2080  8709712904192
# GDP2085_ssp1 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP1\GDP2085_ssp1.tif gdp
# year--> 2085  ....ssp_value-->> SSP1...rescaling_factor--->> 1.2476652054213562
# rescaling_factor 1.2476652054213562
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2085_ssp1.tif
# Sum: 9537093369856.0, Mean: 55070408.0
# row_df:   Scenario  Year            sum
# 0     SSP1  2085  9537093369856
# GDP2090_ssp1 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP1\GDP2090_ssp1.tif gdp
# year--> 2090  ....ssp_value-->> SSP1...rescaling_factor--->> 1.2522447254146996
# rescaling_factor 1.2522447254146996
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2090_ssp1.tif
# Sum: 10206899601408.0, Mean: 58938096.0
# row_df:   Scenario  Year             sum
# 0     SSP1  2090  10206899601408
# GDP2095_ssp1 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP1\GDP2095_ssp1.tif gdp
# year--> 2095  ....ssp_value-->> SSP1...rescaling_factor--->> 1.247843466551794
# rescaling_factor 1.247843466551794
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2095_ssp1.tif
# Sum: 10725408899072.0, Mean: 61932144.0
# row_df:   Scenario  Year             sum
# 0     SSP1  2095  10725408899072
# GDP2100_ssp1 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP1\GDP2100_ssp1.tif gdp
# year--> 2100  ....ssp_value-->> SSP1...rescaling_factor--->> 1.2394813587337652
# rescaling_factor 1.2394813587337652
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2100_ssp1.tif
# Sum: 11148858490880.0, Mean: 64377288.0
# row_df:   Scenario  Year             sum
# 0     SSP1  2100  11148858490880
# GDP2025_ssp2 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP2\GDP2025_ssp2.tif gdp
# year--> 2025  ....ssp_value-->> SSP2...rescaling_factor--->> 1.4498904103343582
# rescaling_factor 1.4498904103343582
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2025_ssp2.tif
# Sum: 1283920363520.0, Mean: 7413663.0
# row_df:   Scenario  Year            sum
# 0     SSP2  2025  1283920363520
# GDP2030_ssp2 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP2\GDP2030_ssp2.tif gdp
# year--> 2030  ....ssp_value-->> SSP2...rescaling_factor--->> 1.307562110906363
# rescaling_factor 1.307562110906363
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2030_ssp2.tif
# Sum: 1472195985408.0, Mean: 8500811.0
# row_df:   Scenario  Year            sum
# 0     SSP2  2030  1472195985408
# GDP2035_ssp2 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP2\GDP2035_ssp2.tif gdp
# year--> 2035  ....ssp_value-->> SSP2...rescaling_factor--->> 1.294113217597669
# rescaling_factor 1.294113217597669
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2035_ssp2.tif
# Sum: 1711614066688.0, Mean: 9883268.0
# row_df:   Scenario  Year            sum
# 0     SSP2  2035  1711614066688
# GDP2040_ssp2 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP2\GDP2040_ssp2.tif gdp
# year--> 2040  ....ssp_value-->> SSP2...rescaling_factor--->> 1.2739633915245898
# rescaling_factor 1.2739633915245898
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2040_ssp2.tif
# Sum: 1968986128384.0, Mean: 11369396.0
# row_df:   Scenario  Year            sum
# 0     SSP2  2040  1968986128384
# GDP2045_ssp2 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP2\GDP2045_ssp2.tif gdp
# year--> 2045  ....ssp_value-->> SSP2...rescaling_factor--->> 1.2555629698022182
# rescaling_factor 1.2555629698022182
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2045_ssp2.tif
# Sum: 2261635825664.0, Mean: 13059225.0
# row_df:   Scenario  Year            sum
# 0     SSP2  2045  2261635825664
# GDP2050_ssp2 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP2\GDP2050_ssp2.tif gdp
# year--> 2050  ....ssp_value-->> SSP2...rescaling_factor--->> 1.2361903458386023
# rescaling_factor 1.2361903458386023
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2050_ssp2.tif
# Sum: 2591491883008.0, Mean: 14963893.0
# row_df:   Scenario  Year            sum
# 0     SSP2  2050  2591491883008
# GDP2055_ssp2 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP2\GDP2055_ssp2.tif gdp
# year--> 2055  ....ssp_value-->> SSP2...rescaling_factor--->> 1.212673293977635
# rescaling_factor 1.212673293977635
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2055_ssp2.tif
# Sum: 2943179816960.0, Mean: 16994624.0
# row_df:   Scenario  Year            sum
# 0     SSP2  2055  2943179816960
# GDP2060_ssp2 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP2\GDP2060_ssp2.tif gdp
# year--> 2060  ....ssp_value-->> SSP2...rescaling_factor--->> 1.1915713368910514
# rescaling_factor 1.1915713368910514
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2060_ssp2.tif
# Sum: 3343548678144.0, Mean: 19306448.0
# row_df:   Scenario  Year            sum
# 0     SSP2  2060  3343548678144
# GDP2065_ssp2 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP2\GDP2065_ssp2.tif gdp
# year--> 2065  ....ssp_value-->> SSP2...rescaling_factor--->> 1.175616104618844
# rescaling_factor 1.175616104618844
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2065_ssp2.tif
# Sum: 3788246876160.0, Mean: 21874242.0
# row_df:   Scenario  Year            sum
# 0     SSP2  2065  3788246876160
# GDP2070_ssp2 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP2\GDP2070_ssp2.tif gdp
# year--> 2070  ....ssp_value-->> SSP2...rescaling_factor--->> 1.1644250303455692
# rescaling_factor 1.1644250303455692
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2070_ssp2.tif
# Sum: 4274177179648.0, Mean: 24680120.0
# row_df:   Scenario  Year            sum
# 0     SSP2  2070  4274177179648
# GDP2075_ssp2 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP2\GDP2075_ssp2.tif gdp
# year--> 2075  ....ssp_value-->> SSP2...rescaling_factor--->> 1.1546499470831542
# rescaling_factor 1.1546499470831542
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2075_ssp2.tif
# Sum: 4800253001728.0, Mean: 27717808.0
# row_df:   Scenario  Year            sum
# 0     SSP2  2075  4800253001728
# GDP2080_ssp2 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP2\GDP2080_ssp2.tif gdp
# year--> 2080  ....ssp_value-->> SSP2...rescaling_factor--->> 1.1300843450463955
# rescaling_factor 1.1300843450463955
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2080_ssp2.tif
# Sum: 5274384465920.0, Mean: 30455556.0
# row_df:   Scenario  Year            sum
# 0     SSP2  2080  5274384465920
# GDP2085_ssp2 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP2\GDP2085_ssp2.tif gdp
# year--> 2085  ....ssp_value-->> SSP2...rescaling_factor--->> 1.0978783689225329
# rescaling_factor 1.0978783689225329
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2085_ssp2.tif
# Sum: 5700836655104.0, Mean: 32917992.0
# row_df:   Scenario  Year            sum
# 0     SSP2  2085  5700836655104
# GDP2090_ssp2 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP2\GDP2090_ssp2.tif gdp
# year--> 2090  ....ssp_value-->> SSP2...rescaling_factor--->> 1.06676091139824
# rescaling_factor 1.06676091139824
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2090_ssp2.tif
# Sum: 6113468612608.0, Mean: 35300628.0
# row_df:   Scenario  Year            sum
# 0     SSP2  2090  6113468612608
# GDP2095_ssp2 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP2\GDP2095_ssp2.tif gdp
# year--> 2095  ....ssp_value-->> SSP2...rescaling_factor--->> 1.044666655263964
# rescaling_factor 1.044666655263964
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2095_ssp2.tif
# Sum: 6555310751744.0, Mean: 37851928.0
# row_df:   Scenario  Year            sum
# 0     SSP2  2095  6555310751744
# GDP2100_ssp2 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP2\GDP2100_ssp2.tif gdp
# year--> 2100  ....ssp_value-->> SSP2...rescaling_factor--->> 1.0331182517786004
# rescaling_factor 1.0331182517786004
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2100_ssp2.tif
# Sum: 7052726894592.0, Mean: 40724128.0
# row_df:   Scenario  Year            sum
# 0     SSP2  2100  7052726894592
# GDP2025_ssp3 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP3\GDP2025_ssp3.tif gdp
# year--> 2025  ....ssp_value-->> SSP3...rescaling_factor--->> 1.5451987111957333
# rescaling_factor 1.5451987111957333
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2025_ssp3.tif
# Sum: 1394878447616.0, Mean: 8054221.5
# row_df:   Scenario  Year            sum
# 0     SSP3  2025  1394878447616
# GDP2030_ssp3 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP3\GDP2030_ssp3.tif gdp
# year--> 2030  ....ssp_value-->> SSP3...rescaling_factor--->> 1.4611465257797056
# rescaling_factor 1.4611465257797056
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2030_ssp3.tif
# Sum: 1621384232960.0, Mean: 9362098.0
# row_df:   Scenario  Year            sum
# 0     SSP3  2030  1621384232960
# GDP2035_ssp3 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP3\GDP2035_ssp3.tif gdp
# year--> 2035  ....ssp_value-->> SSP3...rescaling_factor--->> 1.5073133868720687
# rescaling_factor 1.5073133868720687
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2035_ssp3.tif
# Sum: 1865015492608.0, Mean: 10768858.0
# row_df:   Scenario  Year            sum
# 0     SSP3  2035  1865015492608
# GDP2040_ssp3 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP3\GDP2040_ssp3.tif gdp
# year--> 2040  ....ssp_value-->> SSP3...rescaling_factor--->> 1.551132873383531
# rescaling_factor 1.551132873383531
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2040_ssp3.tif
# Sum: 2121105408000.0, Mean: 12247769.0
# row_df:   Scenario  Year            sum
# 0     SSP3  2040  2121105408000
# GDP2045_ssp3 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP3\GDP2045_ssp3.tif gdp
# year--> 2045  ....ssp_value-->> SSP3...rescaling_factor--->> 1.590190528567158
# rescaling_factor 1.590190528567158
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2045_ssp3.tif
# Sum: 2377050226688.0, Mean: 13725656.0
# row_df:   Scenario  Year            sum
# 0     SSP3  2045  2377050226688
# GDP2050_ssp3 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP3\GDP2050_ssp3.tif gdp
# year--> 2050  ....ssp_value-->> SSP3...rescaling_factor--->> 1.6220809729450576
# rescaling_factor 1.6220809729450576
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2050_ssp3.tif
# Sum: 2630060605440.0, Mean: 15186598.0
# row_df:   Scenario  Year            sum
# 0     SSP3  2050  2630060605440
# GDP2055_ssp3 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP3\GDP2055_ssp3.tif gdp
# year--> 2055  ....ssp_value-->> SSP3...rescaling_factor--->> 1.6365522994038648
# rescaling_factor 1.6365522994038648
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2055_ssp3.tif
# Sum: 2865647845376.0, Mean: 16546935.0
# row_df:   Scenario  Year            sum
# 0     SSP3  2055  2865647845376
# GDP2060_ssp3 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP3\GDP2060_ssp3.tif gdp
# year--> 2060  ....ssp_value-->> SSP3...rescaling_factor--->> 1.6436966271034288
# rescaling_factor 1.6436966271034288
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2060_ssp3.tif
# Sum: 3106261958656.0, Mean: 17936298.0
# row_df:   Scenario  Year            sum
# 0     SSP3  2060  3106261958656
# GDP2065_ssp3 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP3\GDP2065_ssp3.tif gdp
# year--> 2065  ....ssp_value-->> SSP3...rescaling_factor--->> 1.6502983178498878
# rescaling_factor 1.6502983178498878
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2065_ssp3.tif
# Sum: 3356168028160.0, Mean: 19379316.0
# row_df:   Scenario  Year            sum
# 0     SSP3  2065  3356168028160
# GDP2070_ssp3 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP3\GDP2070_ssp3.tif gdp
# year--> 2070  ....ssp_value-->> SSP3...rescaling_factor--->> 1.648115165308054
# rescaling_factor 1.648115165308054
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2070_ssp3.tif
# Sum: 3603016187904.0, Mean: 20804676.0
# row_df:   Scenario  Year            sum
# 0     SSP3  2070  3603016187904
# GDP2075_ssp3 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP3\GDP2075_ssp3.tif gdp
# year--> 2075  ....ssp_value-->> SSP3...rescaling_factor--->> 1.626859269128127
# rescaling_factor 1.626859269128127
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2075_ssp3.tif
# Sum: 3827478560768.0, Mean: 22100776.0
# row_df:   Scenario  Year            sum
# 0     SSP3  2075  3827478560768
# GDP2080_ssp3 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP3\GDP2080_ssp3.tif gdp
# year--> 2080  ....ssp_value-->> SSP3...rescaling_factor--->> 1.5897789406338838
# rescaling_factor 1.5897789406338838
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2080_ssp3.tif
# Sum: 4020697563136.0, Mean: 23216468.0
# row_df:   Scenario  Year            sum
# 0     SSP3  2080  4020697563136
# GDP2085_ssp3 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP3\GDP2085_ssp3.tif gdp
# year--> 2085  ....ssp_value-->> SSP3...rescaling_factor--->> 1.544295414993082
# rescaling_factor 1.544295414993082
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2085_ssp3.tif
# Sum: 4185263702016.0, Mean: 24166712.0
# row_df:   Scenario  Year            sum
# 0     SSP3  2085  4185263702016
# GDP2090_ssp3 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP3\GDP2090_ssp3.tif gdp
# year--> 2090  ....ssp_value-->> SSP3...rescaling_factor--->> 1.491697758256867
# rescaling_factor 1.491697758256867
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2090_ssp3.tif
# Sum: 4326009864192.0, Mean: 24979414.0
# row_df:   Scenario  Year            sum
# 0     SSP3  2090  4326009864192
# GDP2095_ssp3 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP3\GDP2095_ssp3.tif gdp
# year--> 2095  ....ssp_value-->> SSP3...rescaling_factor--->> 1.4336237011641195
# rescaling_factor 1.4336237011641195
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2095_ssp3.tif
# Sum: 4457694232576.0, Mean: 25739792.0
# row_df:   Scenario  Year            sum
# 0     SSP3  2095  4457694232576
# GDP2100_ssp3 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP3\GDP2100_ssp3.tif gdp
# year--> 2100  ....ssp_value-->> SSP3...rescaling_factor--->> 1.3722988277041428
# rescaling_factor 1.3722988277041428
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2100_ssp3.tif
# Sum: 4588101435392.0, Mean: 26492794.0
# row_df:   Scenario  Year            sum
# 0     SSP3  2100  4588101435392
# GDP2025_ssp4 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP4\GDP2025_ssp4.tif gdp
# year--> 2025  ....ssp_value-->> SSP4...rescaling_factor--->> 1.593531320096404
# rescaling_factor 1.593531320096404
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2025_ssp4.tif
# Sum: 1396100562944.0, Mean: 8061418.0
# row_df:   Scenario  Year            sum
# 0     SSP4  2025  1396100562944
# GDP2030_ssp4 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP4\GDP2030_ssp4.tif gdp
# year--> 2030  ....ssp_value-->> SSP4...rescaling_factor--->> 1.5208437340233365
# rescaling_factor 1.5208437340233365
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2030_ssp4.tif
# Sum: 1576223768576.0, Mean: 9101492.0
# row_df:   Scenario  Year            sum
# 0     SSP4  2030  1576223768576
# GDP2035_ssp4 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP4\GDP2035_ssp4.tif gdp
# year--> 2035  ....ssp_value-->> SSP4...rescaling_factor--->> 1.6115109970334087
# rescaling_factor 1.6115109970334087
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2035_ssp4.tif
# Sum: 1782596108288.0, Mean: 10293136.0
# row_df:   Scenario  Year            sum
# 0     SSP4  2035  1782596108288
# GDP2040_ssp4 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP4\GDP2040_ssp4.tif gdp
# year--> 2040  ....ssp_value-->> SSP4...rescaling_factor--->> 1.7009684851225737
# rescaling_factor 1.7009684851225737
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2040_ssp4.tif
# Sum: 1973858467840.0, Mean: 11397530.0
# row_df:   Scenario  Year            sum
# 0     SSP4  2040  1973858467840
# GDP2045_ssp4 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP4\GDP2045_ssp4.tif gdp
# year--> 2045  ....ssp_value-->> SSP4...rescaling_factor--->> 1.7964570945772274
# rescaling_factor 1.7964570945772274
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2045_ssp4.tif
# Sum: 2150952730624.0, Mean: 12420115.0
# row_df:   Scenario  Year            sum
# 0     SSP4  2045  2150952730624
# GDP2050_ssp4 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP4\GDP2050_ssp4.tif gdp
# year--> 2050  ....ssp_value-->> SSP4...rescaling_factor--->> 1.897542996947686
# rescaling_factor 1.897542996947686
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2050_ssp4.tif
# Sum: 2305209663488.0, Mean: 13310831.0
# row_df:   Scenario  Year            sum
# 0     SSP4  2050  2305209663488
# GDP2055_ssp4 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP4\GDP2055_ssp4.tif gdp
# year--> 2055  ....ssp_value-->> SSP4...rescaling_factor--->> 1.9946798592035213
# rescaling_factor 1.9946798592035213
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2055_ssp4.tif
# Sum: 2435888185344.0, Mean: 14065400.0
# row_df:   Scenario  Year            sum
# 0     SSP4  2055  2435888185344
# GDP2060_ssp4 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP4\GDP2060_ssp4.tif gdp
# year--> 2060  ....ssp_value-->> SSP4...rescaling_factor--->> 2.1030302522471933
# rescaling_factor 2.1030302522471933
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2060_ssp4.tif
# Sum: 2553625182208.0, Mean: 14745242.0
# row_df:   Scenario  Year            sum
# 0     SSP4  2060  2553625182208
# GDP2065_ssp4 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP4\GDP2065_ssp4.tif gdp
# year--> 2065  ....ssp_value-->> SSP4...rescaling_factor--->> 2.2367222648928893
# rescaling_factor 2.2367222648928893
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2065_ssp4.tif
# Sum: 2674819596288.0, Mean: 15445047.0
# row_df:   Scenario  Year            sum
# 0     SSP4  2065  2674819596288
# GDP2070_ssp4 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP4\GDP2070_ssp4.tif gdp
# year--> 2070  ....ssp_value-->> SSP4...rescaling_factor--->> 2.391581103601341
# rescaling_factor 2.391581103601341
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2070_ssp4.tif
# Sum: 2791908048896.0, Mean: 16121144.0
# row_df:   Scenario  Year            sum
# 0     SSP4  2070  2791908048896
# GDP2075_ssp4 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP4\GDP2075_ssp4.tif gdp
# year--> 2075  ....ssp_value-->> SSP4...rescaling_factor--->> 2.5572708456055846
# rescaling_factor 2.5572708456055846
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2075_ssp4.tif
# Sum: 2898462769152.0, Mean: 16736416.0
# row_df:   Scenario  Year            sum
# 0     SSP4  2075  2898462769152
# GDP2080_ssp4 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP4\GDP2080_ssp4.tif gdp
# year--> 2080  ....ssp_value-->> SSP4...rescaling_factor--->> 2.734957726030616
# rescaling_factor 2.734957726030616
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2080_ssp4.tif
# Sum: 2988232409088.0, Mean: 17254768.0
# row_df:   Scenario  Year            sum
# 0     SSP4  2080  2988232409088
# GDP2085_ssp4 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP4\GDP2085_ssp4.tif gdp
# year--> 2085  ....ssp_value-->> SSP4...rescaling_factor--->> 2.9290833549498902
# rescaling_factor 2.9290833549498902
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2085_ssp4.tif
# Sum: 3071651086336.0, Mean: 17736446.0
# row_df:   Scenario  Year            sum
# 0     SSP4  2085  3071651086336
# GDP2090_ssp4 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP4\GDP2090_ssp4.tif gdp
# year--> 2090  ....ssp_value-->> SSP4...rescaling_factor--->> 3.1391967624821806
# rescaling_factor 3.1391967624821806
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2090_ssp4.tif
# Sum: 3138303295488.0, Mean: 18121312.0
# row_df:   Scenario  Year            sum
# 0     SSP4  2090  3138303295488
# GDP2095_ssp4 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP4\GDP2095_ssp4.tif gdp
# year--> 2095  ....ssp_value-->> SSP4...rescaling_factor--->> 3.3622292820467465
# rescaling_factor 3.3622292820467465
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2095_ssp4.tif
# Sum: 3202755854336.0, Mean: 18493478.0
# row_df:   Scenario  Year            sum
# 0     SSP4  2095  3202755854336
# GDP2100_ssp4 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP4\GDP2100_ssp4.tif gdp
# year--> 2100  ....ssp_value-->> SSP4...rescaling_factor--->> 3.604853044097641
# rescaling_factor 3.604853044097641
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2100_ssp4.tif
# Sum: 3267064233984.0, Mean: 18864810.0
# row_df:   Scenario  Year            sum
# 0     SSP4  2100  3267064233984
# GDP2025_ssp5 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP5\GDP2025_ssp5.tif gdp
# year--> 2025  ....ssp_value-->> SSP5...rescaling_factor--->> 1.2803307855735029
# rescaling_factor 1.2803307855735029
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2025_ssp5.tif
# Sum: 1116145713152.0, Mean: 6444892.0
# row_df:   Scenario  Year            sum
# 0     SSP5  2025  1116145713152
# GDP2030_ssp5 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP5\GDP2030_ssp5.tif gdp
# year--> 2030  ....ssp_value-->> SSP5...rescaling_factor--->> 1.0750228135188074
# rescaling_factor 1.0750228135188074
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2030_ssp5.tif
# Sum: 1295436218368.0, Mean: 7480158.0
# row_df:   Scenario  Year            sum
# 0     SSP5  2030  1295436218368
# GDP2035_ssp5 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP5\GDP2035_ssp5.tif gdp
# year--> 2035  ....ssp_value-->> SSP5...rescaling_factor--->> 1.037559107017283
# rescaling_factor 1.037559107017283
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2035_ssp5.tif
# Sum: 1735605616640.0, Mean: 10021801.0
# row_df:   Scenario  Year            sum
# 0     SSP5  2035  1735605616640
# GDP2040_ssp5 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP5\GDP2040_ssp5.tif gdp
# year--> 2040  ....ssp_value-->> SSP5...rescaling_factor--->> 1.0053200283188015
# rescaling_factor 1.0053200283188015
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2040_ssp5.tif
# Sum: 2278107643904.0, Mean: 13154338.0
# row_df:   Scenario  Year            sum
# 0     SSP5  2040  2278107643904
# GDP2045_ssp5 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP5\GDP2045_ssp5.tif gdp
# year--> 2045  ....ssp_value-->> SSP5...rescaling_factor--->> 0.9971924600548538
# rescaling_factor 0.9971924600548538
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2045_ssp5.tif
# Sum: 2963627311104.0, Mean: 17112692.0
# row_df:   Scenario  Year            sum
# 0     SSP5  2045  2963627311104
# GDP2050_ssp5 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP5\GDP2050_ssp5.tif gdp
# year--> 2050  ....ssp_value-->> SSP5...rescaling_factor--->> 0.9911587147914966
# rescaling_factor 0.9911587147914966
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2050_ssp5.tif
# Sum: 3747065102336.0, Mean: 21636448.0
# row_df:   Scenario  Year            sum
# 0     SSP5  2050  3747065102336
# GDP2055_ssp5 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP5\GDP2055_ssp5.tif gdp
# year--> 2055  ....ssp_value-->> SSP5...rescaling_factor--->> 0.988710613921209
# rescaling_factor 0.988710613921209
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2055_ssp5.tif
# Sum: 4625234132992.0, Mean: 26707206.0
# row_df:   Scenario  Year            sum
# 0     SSP5  2055  4625234132992
# GDP2060_ssp5 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP5\GDP2060_ssp5.tif gdp
# year--> 2060  ....ssp_value-->> SSP5...rescaling_factor--->> 0.965234242556162
# rescaling_factor 0.965234242556162
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2060_ssp5.tif
# Sum: 5448539832320.0, Mean: 31461170.0
# row_df:   Scenario  Year            sum
# 0     SSP5  2060  5448539832320
# GDP2065_ssp5 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP5\GDP2065_ssp5.tif gdp
# year--> 2065  ....ssp_value-->> SSP5...rescaling_factor--->> 0.9457178526519416
# rescaling_factor 0.9457178526519416
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2065_ssp5.tif
# Sum: 6265658933248.0, Mean: 36179412.0
# row_df:   Scenario  Year            sum
# 0     SSP5  2065  6265658933248
# GDP2070_ssp5 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP5\GDP2070_ssp5.tif gdp
# year--> 2070  ....ssp_value-->> SSP5...rescaling_factor--->> 0.9326672529970772
# rescaling_factor 0.9326672529970772
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2070_ssp5.tif
# Sum: 7110601474048.0, Mean: 41058312.0
# row_df:   Scenario  Year            sum
# 0     SSP5  2070  7110601474048
# GDP2075_ssp5 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP5\GDP2075_ssp5.tif gdp
# year--> 2075  ....ssp_value-->> SSP5...rescaling_factor--->> 0.9337029910159964
# rescaling_factor 0.9337029910159964
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2075_ssp5.tif
# Sum: 8022132260864.0, Mean: 46321708.0
# row_df:   Scenario  Year            sum
# 0     SSP5  2075  8022132260864
# GDP2080_ssp5 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP5\GDP2080_ssp5.tif gdp
# year--> 2080  ....ssp_value-->> SSP5...rescaling_factor--->> 0.9415661962337576
# rescaling_factor 0.9415661962337576
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2080_ssp5.tif
# Sum: 8984466554880.0, Mean: 51878456.0
# row_df:   Scenario  Year            sum
# 0     SSP5  2080  8984466554880
# GDP2085_ssp5 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP5\GDP2085_ssp5.tif gdp
# year--> 2085  ....ssp_value-->> SSP5...rescaling_factor--->> 0.9488674244579848
# rescaling_factor 0.9488674244579848
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2085_ssp5.tif
# Sum: 9913588776960.0, Mean: 57243428.0
# row_df:   Scenario  Year            sum
# 0     SSP5  2085  9913588776960
# GDP2090_ssp5 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP5\GDP2090_ssp5.tif gdp
# year--> 2090  ....ssp_value-->> SSP5...rescaling_factor--->> 0.9457539904852056
# rescaling_factor 0.9457539904852056
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2090_ssp5.tif
# Sum: 10654812471296.0, Mean: 61523432.0
# row_df:   Scenario  Year             sum
# 0     SSP5  2090  10654812471296
# GDP2095_ssp5 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP5\GDP2095_ssp5.tif gdp
# year--> 2095  ....ssp_value-->> SSP5...rescaling_factor--->> 0.9245154404904644
# rescaling_factor 0.9245154404904644
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2095_ssp5.tif
# Sum: 11132561522688.0, Mean: 64282068.0
# row_df:   Scenario  Year             sum
# 0     SSP5  2095  11132561522688
# GDP2100_ssp5 D:/Aziz/GFDRR/CRP/FCS/data\gdp\SSP5\GDP2100_ssp5.tif gdp
# year--> 2100  ....ssp_value-->> SSP5...rescaling_factor--->> 0.8855813520871428
# rescaling_factor 0.8855813520871428
# clip_and_export_rescale_raster done 1
# Opening: D:\Aziz\GFDRR\CRP\FCS\02-process-output\rasters\Bangladesh_processed_gdp_GDP2100_ssp5.tif
# Sum: 11277419151360.0, Mean: 65118512.0
# row_df:   Scenario  Year             sum
# 0     SSP5  2100  11277419151360
# No matching raster found for suffix 'heatflux_AHE_2050_01_average.tif' in Bangladesh files.
# No matching raster found for suffix 'heatflux_AHE_2050_02_average.tif' in Bangladesh files.
# No matching raster found for suffix 'heatflux_AHE_2050_03_average.tif' in Bangladesh files.
# No matching raster found for suffix 'heatflux_AHE_2050_04_average.tif' in Bangladesh files.
# No matching raster found for suffix 'heatflux_AHE_2050_05_average.tif' in Bangladesh files.
# No matching raster found for suffix 'heatflux_AHE_2050_06_average.tif' in Bangladesh files.
# No matching raster found for suffix 'heatflux_AHE_2050_07_average.tif' in Bangladesh files.
# No matching raster found for suffix 'heatflux_AHE_2050_08_average.tif' in Bangladesh files.
# No matching raster found for suffix 'heatflux_AHE_2050_09_average.tif' in Bangladesh files.
# No matching raster found for suffix 'heatflux_AHE_2050_10_average.tif' in Bangladesh files.
# No matching raster found for suffix 'heatflux_AHE_2050_11_average.tif' in Bangladesh files.
# No matching raster found for suffix 'heatflux_AHE_2050_12_average.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp1_day_sum.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp1_day_win.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp1_nig_sum.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp1_nig_win.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp2_day_sum.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp2_day_win.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp2_nig_sum.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp2_nig_win.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp3_day_sum.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp3_day_win.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp3_nig_sum.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp3_nig_win.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp4_day_sum.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp4_day_win.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp4_nig_sum.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp4_nig_win.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp5_day_sum.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp5_day_win.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp5_nig_sum.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanheatisland_urban-ssp5_nig_win.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp1_2010.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp1_2020.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp1_2030.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp1_2040.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp1_2050.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp1_2060.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp1_2070.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp1_2080.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp1_2090.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp1_2100.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp2_2010.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp2_2020.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp2_2030.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp2_2040.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp2_2050.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp2_2060.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp2_2070.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp2_2080.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp2_2090.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp2_2100.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp3_2010.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp3_2020.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp3_2030.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp3_2040.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp3_2050.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp3_2060.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp3_2070.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp3_2080.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp3_2090.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp3_2100.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp4_2010.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp4_2020.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp4_2030.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp4_2040.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp4_2050.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp4_2060.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp4_2070.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp4_2080.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp4_2090.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp4_2100.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp5_2010.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp5_2020.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp5_2030.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp5_2040.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp5_2050.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp5_2060.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp5_2070.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp5_2080.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp5_2090.tif' in Bangladesh files.
# No matching raster found for suffix 'urbanland_ssp5_2100.tif' in Bangladesh files.
# Results exported to D:\Aziz\GFDRR\CRP\FCS\02-process-output\tables/gdp_city_to_country_ratios.csv
